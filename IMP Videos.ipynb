# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Robotics/blob/main/IMP%20Videos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LDR:
# https://www.youtube.com/watch?v=g8fk6FsGbEQ
#
# Sensors:
# https://www.youtube.com/shorts/GZfGOdq11Sk
#
# Testing PIR Sensor:
# https://www.youtube.com/watch?v=V1QY9hjipc0
#
# Testing PIR motion Sensor on breadboard:
# https://www.youtube.com/watch?v=NZ1RHtF2rEA
#
#
# The Rise Of Technology-Augmented Reality(AR), Virtual Reality(VR) And Mixed Reality(MR):
# https://www.youtube.com/watch?v=XLP4YTpUpBI

# %% [markdown]
# Robots in real life
# https://www.youtube.com/watch?v=I1HtP_qmtH8&list=PPSV
#
# Invention of Robots
# https://www.youtube.com/watch?v=negyqkJ8UKM&list=PPSV
#
# Types of robots
# https://www.youtube.com/watch?v=179jyHqRYD0&list=PPSV
#
# Robots basics
# https://www.youtube.com/watch?v=mm8YD99OHuA&list=PPSV
#
# Robotics
# https://www.youtube.com/watch?v=xbyEP0M9w7k&list=PPSV
#
# Fundamentals of Robotics
# https://www.youtube.com/watch?v=KMgivuauibk&list=PPSV

# %% [markdown]
# https://www.youtube.com/watch?v=cd04o5yqSAU&list=PLlBVuTSjOrclb0iCMSRpS_H1lSrlSVeEm

# %% [markdown]
# Ultra Sonic Sensor Testing
# https://www.youtube.com/watch?v=FHFYnWaZZQ0
