# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Robotics/blob/main/Sensors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.youtube.com/watch?v=g8fk6FsGbEQ
#
# https://www.youtube.com/shorts/GZfGOdq11Sk
