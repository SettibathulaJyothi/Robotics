# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Robotics/blob/main/Components.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color=red>**LEDs**</font>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #<font color=red>**Button**</font>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #<font color=red>**Jumper Wires**</font>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #<font color=red>**Bread Board**</font>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #<font color=red>**Arduino**</font>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
